# %%
import pandas as pd
import seaborn as sns

df1 = pd.read_csv("./sample_data/rrhhGenero.csv",sep=";",engine="python", encoding='utf-8')

df2 = df1[{"categoria", "cantidad_varones", "cantidad_mujeres"}]
df2 = df2.loc[0:20]

grafico = sns.pairplot(df2,hue="categoria",palette="Spectral")
